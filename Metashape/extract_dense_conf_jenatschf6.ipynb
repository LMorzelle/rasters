# %%
import pdal
pdal.__version__
import json
import pandas as pd
import numpy as np
import pdal
from pathlib import Path # KW_dense_cloud-22-58.las
import geopandas as gpd
from shapely.geometry import Point
from shapely import wkt
from osgeo import gdal
import rasterio
import rioxarray as rxr
from rasterio.features import shapes

# %%
pdal.__version__
# Out:
# '3.4.5'

# %%
def get_bin_statistics(array, length=1):
    df = pd.DataFrame(array)
    metadata = {
        "bin_x": np.floor(df.loc[:,"X"].min())+length/2,
        "bin_y": np.floor(df.loc[:,"Y"].min())+length/2,
        "bin_count": len(array),
        "bin_conf_sum": df.loc[:,"confidence"].sum()
    }
    
    return pd.DataFrame([metadata])

def get_bin_statistics_without_conf(array, length=1):
    df = pd.DataFrame(array)
    metadata = {
        "bin_x": np.floor(df.loc[:,"X"].min())+length/2,
        "bin_y": np.floor(df.loc[:,"Y"].min())+length/2,
        "bin_count": len(array)
        #"bin_conf_sum": df.loc[:,"Confidence"].sum()
    }
    
    return pd.DataFrame([metadata])

# %%
dc_data = Path(r"P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6")

# %%
data = dc_data
for file_name in ["point_cloud_Jenatschsudf6-*-*.las"]:
    output = pd.DataFrame()
    for path in [i for i in data.glob(file_name)]:
        print(path)
        args = [
                {
                    "type" : "readers.las",
                    "filename" : f"{str(Path(data,path.name))}",
    #                "in_srs" : "EPSG:2056",
                    "extra_dims" : ["confidence=uint8", "normal=uint8"] # for dense cloud
                },
                {
                    "type":"filters.splitter",
                    "length":"1",
                    "origin_x":"2600000.0",
                    "origin_y":"1200000.0"
                }
            ]

        pipeline = pdal.Pipeline(json.dumps(args))
        count = pipeline.execute()
        arrays = pipeline.arrays
        metadata = pipeline.metadata
        log = pipeline.log
        for array in arrays:
            output = pd.concat([output, get_bin_statistics(array)], ignore_index=True)
            
    compiled_output = output.groupby(["bin_x","bin_y"]).sum().reset_index()
    compiled_output
    compiled_output["bin_conf_mean"] = compiled_output.bin_conf_sum/compiled_output.bin_count
    # Convert DataFrame to GeoDataFrame
    gdf = gpd.GeoDataFrame(compiled_output, geometry=gpd.points_from_xy(compiled_output.bin_x, compiled_output.bin_y))
    #gdf = gdf.drop(columns='geometry')
    # Set the CRS (assuming EPSG:32633 based on previous comments)
    gdf.set_crs(epsg=2056, inplace=True)

    gdf.rename(columns={'bin_x': 'x', 'bin_y': 'y'}, inplace=True)
    # Convert GeoDataFrame to rioxarray object
    rioxarray_obj = gdf.set_index(['y', 'x']).to_xarray()
    rioxarray_obj = rioxarray_obj.drop_vars('geometry')
    # Save the rioxarray object to a NetCDF file
    rioxarray_obj.to_netcdf(dc_data / f"dense_cloud_raster.nc")
    rioxarray_obj["bin_conf_mean"].plot()
# Out:
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-0-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-1-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-10-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-11-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-12-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-13-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-14-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-2-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-3-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-4-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-5-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-6-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-7-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-8-9.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-0.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-1.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-2.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-3.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-4.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-5.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-6.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-7.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-8.las
# P:\Korttid\pbm\Jenatsch sud - f6\point_cloud_Jenatschsudf6\point_cloud_Jenatschsudf6-9-9.las
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15840\2994541259.py in ?()
#      32     # Convert DataFrame to GeoDataFrame
#      33     gdf = gpd.GeoDataFrame(compiled_output, geometry=gpd.points_from_xy(compiled_output.bin_x, compiled_output.bin_y))
#      34     gdf = gdf.drop(columns='geometry')
#      35     # Set the CRS (assuming EPSG:32633 based on previous comments)
# ---> 36     gdf.set_crs(epsg=2056, inplace=True)
#      37
#      38     gdf.rename(columns={'bin_x': 'x', 'bin_y': 'y'}, inplace=True)
#      39     # Convert GeoDataFrame to rioxarray object
#
# c:\Users\PBm\AppData\Local\miniconda3\envs\leila\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'set_crs'

# %%
gdf = gpd.GeoDataFrame(compiled_output, geometry=gpd.points_from_xy(compiled_output.bin_x, compiled_output.bin_y))
#gdf = gdf.drop(columns='geometry')
# Set the CRS (assuming EPSG:32633 based on previous comments)
gdf.set_crs(epsg=2056, inplace=True)

gdf.rename(columns={'bin_x': 'x', 'bin_y': 'y'}, inplace=True)
# Convert GeoDataFrame to rioxarray object
rioxarray_obj = gdf.set_index(['y', 'x']).to_xarray()
rioxarray_obj = rioxarray_obj.drop_vars('geometry')
# Save the rioxarray object to a NetCDF file
rioxarray_obj.to_netcdf(dc_data / f"dense_cloud_raster.nc")
rioxarray_obj["bin_conf_mean"].plot()
