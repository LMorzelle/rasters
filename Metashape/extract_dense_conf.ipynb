# %%
import pdal
pdal.__version__
import json
import pandas as pd
import numpy as np
import pdal
from pathlib import Path # KW_dense_cloud-22-58.las
import geopandas as gpd
from shapely.geometry import Point
from shapely import wkt
from osgeo import gdal
import rasterio
import rioxarray as rxr
from rasterio.features import shapes

# %%
pdal.__version__
# Out:
# '3.4.5'

# %%
def get_bin_statistics(array, length=1):
    df = pd.DataFrame(array)
    metadata = {
        "bin_x": np.floor(df.loc[:,"X"].min())+length/2,
        "bin_y": np.floor(df.loc[:,"Y"].min())+length/2,
        "bin_count": len(array),
        "bin_conf_sum": df.loc[:,"confidence"].sum()
    }
    
    return pd.DataFrame([metadata])

def get_bin_statistics_without_conf(array, length=1):
    df = pd.DataFrame(array)
    metadata = {
        "bin_x": np.floor(df.loc[:,"X"].min())+length/2,
        "bin_y": np.floor(df.loc[:,"Y"].min())+length/2,
        "bin_count": len(array)
        #"bin_conf_sum": df.loc[:,"Confidence"].sum()
    }
    
    return pd.DataFrame([metadata])

# %%
dc_data = Path(r"P:\Korttid\pbm\point_cloud")

# %%
data = dc_data
for file_name in ["point_cloud-*-*.las"]:
    output = pd.DataFrame()
    for path in [i for i in data.glob(file_name)]:
        print(path)
        args = [
                {
                    "type" : "readers.las",
                    "filename" : f"{str(Path(data,path.name))}",
    #                "in_srs" : "EPSG:2056",
                    "extra_dims" : ["confidence=uint8", "normal=uint8"] # for dense cloud
                },
                {
                    "type":"filters.splitter",
                    "length":"1",
                    "origin_x":"2600000.0",
                    "origin_y":"1200000.0"
                }
            ]

        pipeline = pdal.Pipeline(json.dumps(args))
        count = pipeline.execute()
        arrays = pipeline.arrays
        metadata = pipeline.metadata
        log = pipeline.log
        for array in arrays:
            output = pd.concat([output, get_bin_statistics(array)], ignore_index=True)
            
    compiled_output = output.groupby(["bin_x","bin_y"]).sum().reset_index()
    compiled_output
    compiled_output["bin_conf_mean"] = compiled_output.bin_conf_sum/compiled_output.bin_count
    # Convert DataFrame to GeoDataFrame
    gdf = gpd.GeoDataFrame(compiled_output, geometry=gpd.points_from_xy(compiled_output.bin_x, compiled_output.bin_y))
    #gdf = gdf.drop(columns='geometry')
    # Set the CRS (assuming EPSG:32633 based on previous comments)
    gdf.set_crs(epsg=2056, inplace=True)

    gdf.rename(columns={'bin_x': 'x', 'bin_y': 'y'}, inplace=True)
    # Convert GeoDataFrame to rioxarray object
    rioxarray_obj = gdf.set_index(['y', 'x']).to_xarray()
    rioxarray_obj = rioxarray_obj.drop_vars('geometry')
    # Save the rioxarray object to a NetCDF file
    rioxarray_obj.to_netcdf(dc_data / f"dense_cloud_raster.nc")
    rioxarray_obj["bin_conf_mean"].plot()
# Out:
# P:\Korttid\pbm\point_cloud\point_cloud-0-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-0-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-1-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-10-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-11-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-12-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-13-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-14-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-15-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-16-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-17-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-18-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-19-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-2-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-3-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-4-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-5-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-6-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-7-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-8-9.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-0.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-1.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-10.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-11.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-12.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-13.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-14.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-15.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-16.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-2.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-3.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-4.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-5.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-6.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-7.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-8.las
# P:\Korttid\pbm\point_cloud\point_cloud-9-9.las
