# %%
import rioxarray  # Import the rioxarray library for reading and writing geospatial raster data
from pathlib import Path
import matplotlib.pyplot as plt  # Import the matplotlib library for plotting
from pathlib import Path
from create_comparison import create_comparison_figure

# Load the DEM file
dem_path = Path(r"D:\NFETRA\2024\01-photogrammetry\20240910\o1\export\DEM.tif")  # Define the path to the DEM (Digital Elevation Model) file
dem = rioxarray.open_rasterio(dem_path, masked=True)  # Open the DEM file using rioxarray and set the no data value to -32767

swiss_dem_path = Path(r"D:\NFETRA\Projet QGIS\DATA\swiss_topo_files\DEM_swisstopo\DEM_ForclaAgnel_swisstopo.tif")
swiss_dem = rioxarray.open_rasterio(swiss_dem_path, masked=True)   # Open the DEM file using rio"array
# Out:
# c:\Users\leila\miniconda3\envs\raster\Lib\site-packages\pyproj\crs\_cf1x8.py:515: UserWarning: angle from rectified to skew grid parameter lost in conversion to CF
#   warnings.warn(

# %%
create_comparison_figure(dem_path, swiss_dem_path, vmin=-2, vmax=2, crop_size=1500, xtickdelta=1000, ytickdelta=1000)
# Out:
# c:\Users\leila\miniconda3\envs\raster\Lib\site-packages\pyproj\crs\_cf1x8.py:515: UserWarning: angle from rectified to skew grid parameter lost in conversion to CF
#   warnings.warn(
# c:\Users\leila\miniconda3\envs\raster\Lib\site-packages\pyproj\crs\_cf1x8.py:515: UserWarning: angle from rectified to skew grid parameter lost in conversion to CF
#   warnings.warn(
# c:\Users\leila\git\rasters\create_comparison.py:43: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels(ax.get_yticklabels(), rotation=90, va='center')
# c:\Users\leila\git\rasters\create_comparison.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=0, ha='center')
